# %% [markdown]
# https://www.kaggle.com/competitions/fake-news/data

# %%
#Importing the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submit = pd.read_csv('submit.csv')

# %%
# Displaying rows and columns in dataset

print("There are {} number of rows and {} number of columns for training.".format(train.shape[0],train.shape[1]))
print("There are {} number of rows and {} number of columns for testing.".format(test.shape[0],test.shape[1]))
# Out:
# There are 20800 number of rows and 5 number of columns for training.
# There are 5200 number of rows and 4 number of columns for testing.

# %%
train.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
#Checking the datatypes

train.dtypes
# Out:
# id         int64
# title     object
# author    object
# text      object
# label      int64
# dtype: object

# %%
#Checking for null values

train.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
#Filling the nan values

train = train.fillna('')

# %%
train.isnull().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
test = test.fillna('')

# %%
train.author.nunique()
# Out:
# 4202

# %%
test.author.nunique()
# Out:
# 1733

# %%
# Class Distribution
# 1: Unreliable
# 0: Reliable

import seaborn as sns
sns.countplot(x='label', data= train)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
import string
import re
from nltk.corpus import stopwords

# %%
stop_word = stopwords.words('english')
def cleaning_data(x):
    #lower the value
    x =x.lower()
   
    #removing all the stopwords
    x = ' '.join([word for word in x.split(' ') if word not in stop_word])
    
    return x

# %%
stop_word
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
train.title = train.title.apply(cleaning_data)
train.author = train.author.apply(cleaning_data)
train.text =  train.text.apply(cleaning_data)

# %%
train.head()
# Out:
#    id                                              title              author  \
# 0   0  house dem aide: didn’t even see comey’s letter...       darrell lucus
# 1   1  flynn: hillary clinton, big woman campus - bre...     daniel j. flynn
# 2   2                              truth might get fired  consortiumnews.com
# 3   3  15 civilians killed single us airstrike identi...     jessica purkiss
# 4   4  iranian woman jailed fictional unpublished sto...      howard portnoy
#
#                                                 text  label
# 0  house dem aide: didn’t even see comey’s letter...      1
# 1  ever get feeling life circles roundabout rathe...      0
# 2  truth might get fired october 29, 2016 \nthe t...      1
# 3  videos 15 civilians killed single us airstrike...      1
# 4  print \nan iranian woman sentenced six years p...      1

# %%
from nltk.stem.porter import PorterStemmer
port = PorterStemmer()
def stemming(x):
    x = ' '.join([port.stem(word) for word in x.split(' ')])
    return x

# %%
train.text =  train.text.apply(stemming)
train.title =  train.title.apply(stemming)

# %%
train.head()
# Out:
#    id                                              title              author  \
# 0   0  hous dem aide: didn’t even see comey’ letter j...       darrell lucus
# 1   1  flynn: hillari clinton, big woman campu - brei...     daniel j. flynn
# 2   2                               truth might get fire  consortiumnews.com
# 3   3        15 civilian kill singl us airstrik identifi     jessica purkiss
# 4   4  iranian woman jail fiction unpublish stori wom...      howard portnoy
#
#                                                 text  label
# 0  hous dem aide: didn’t even see comey’ letter j...      1
# 1  ever get feel life circl roundabout rather hea...      0
# 2  truth might get fire octob 29, 2016 \nthe tens...      1
# 3  video 15 civilian kill singl us airstrik ident...      1
# 4  print \nan iranian woman sentenc six year pris...      1

# %%
train['content'] = train.title + ' '+train.author

# %%
train.drop(['title' , 'author'] , axis = 1 , inplace = True)

# %%
train.head()
# Out:
#    id                                               text  label  \
# 0   0  hous dem aide: didn’t even see comey’ letter j...      1
# 1   1  ever get feel life circl roundabout rather hea...      0
# 2   2  truth might get fire octob 29, 2016 \nthe tens...      1
# 3   3  video 15 civilian kill singl us airstrik ident...      1
# 4   4  print \nan iranian woman sentenc six year pris...      1
#
#                                              content
# 0  hous dem aide: didn’t even see comey’ letter j...
# 1  flynn: hillari clinton, big woman campu - brei...
# 2            truth might get fire consortiumnews.com
# 3  15 civilian kill singl us airstrik identifi je...
# 4  iranian woman jail fiction unpublish stori wom...

# %%
test.title = test.title.apply(cleaning_data)
test.author = test.author.apply(cleaning_data)
test.text =  test.text.apply(cleaning_data)

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  specter trump loosens tongues, purse strings, ...
# 1  20801  russian warships ready strike terrorists near ...
# 2  20802  #nodapl: native american leaders vow stay wint...
# 3  20803  tim tebow attempt another comeback, time baseb...
# 4  20804                    keiser report: meme wars (e995)
#
#                     author                                               text
# 0         david streitfeld  palo alto, calif.  —   years scorning politica...
# 1                           russian warships ready strike terrorists near ...
# 2            common dreams  videos #nodapl: native american leaders vow st...
# 3            daniel victor  first don’t succeed, try different sport. tim ...
# 4  truth broadcast network  42 mins ago 1 views 0 comments 0 likes 'for fi...

# %%
test.text =  test.text.apply(stemming)
test.title =  test.title.apply(stemming)

# %%
test['content'] = test.title + ' ' + test.author

# %%
test.drop(['title' , 'author'] , axis =1 ,inplace = True)

# %%
test.head()
# Out:
#       id                                               text  \
# 0  20800  palo alto, calif.  —   year scorn polit proces...
# 1  20801  russian warship readi strike terrorist near al...
# 2  20802  video #nodapl: nativ american leader vow stay ...
# 3  20803  first don’t succeed, tri differ sport. tim teb...
# 4  20804  42 min ago 1 view 0 comment 0 like 'for first ...
#
#                                              content
# 0  specter trump loosen tongues, purs strings, si...
# 1  russian warship readi strike terrorist near al...
# 2  #nodapl: nativ american leader vow stay winter...
# 3  tim tebow attempt anoth comeback, time basebal...
# 4  keiser report: meme war (e995) truth broadcast...

# %%
from wordcloud import WordCloud

# initialize the word cloud
wordcloud = WordCloud(background_color='black', width=800, height=600)
# generate the word cloud
text_cloud = wordcloud.generate(" ".join(train['content']))
# plotting the word cloud
plt.figure(figsize=(20,30))
plt.imshow(text_cloud)
plt.axis('off')
plt.show()

# %%
# reliable news (0)
reliable_news = " ".join(train[train['label']==0]['content'])
wc = wordcloud.generate(reliable_news)
plt.figure(figsize=(20,30))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
# unreliable news (1)
unreliable_news  = ' '.join(train[train['label']==1]['content'])
wc= wordcloud.generate(unreliable_news)
plt.figure(figsize=(20,30))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
y = train.label
train.drop(['label'] , axis =1 , inplace =True)

# %%
X = train.content.values
y = y.values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(X)
X = vectorizer.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test = train_test_split(X , y )

# %%
test_ = test.content.values

# %%
test_ = vectorizer.transform(test_)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_predicted = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score1=accuracy_score( y_test,X_predicted)
print(score1)
# Out:
# 0.9692307692307692

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,X_predicted)
# Out:
# array([[2505,  142],
#        [  18, 2535]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,X_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      2647
#            1       0.95      0.99      0.97      2553
#
#     accuracy                           0.97      5200
#    macro avg       0.97      0.97      0.97      5200
# weighted avg       0.97      0.97      0.97      5200

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
model2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_predicted2 = model2.predict(X_test)
score2=accuracy_score( y_test,X_predicted2)
print(score2)
# Out:
# 0.9901923076923077

# %%
print(classification_report(y_test,X_predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2647
#            1       0.99      0.99      0.99      2553
#
#     accuracy                           0.99      5200
#    macro avg       0.99      0.99      0.99      5200
# weighted avg       0.99      0.99      0.99      5200

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
model3 = RandomForestClassifier()
model3.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
X_predicted3 = model3.predict(X_test)
score3=accuracy_score( y_test,X_predicted3)
print(score3)
# Out:
# 0.9919230769230769

# %%
print(classification_report(y_test,X_predicted3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2647
#            1       0.99      1.00      0.99      2553
#
#     accuracy                           0.99      5200
#    macro avg       0.99      0.99      0.99      5200
# weighted avg       0.99      0.99      0.99      5200

# %%
results = pd.DataFrame([["Logistic Regression",score1],["Decision Tree",score2],
                       ["Random Forest",score3]],columns=["Model","Accuracy"])

results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.969231
# 1        Decision Tree  0.990192
# 2        Random Forest  0.991923

# %%
prediction1 = model3.predict(test_)

# %%
submit.head()
# Out:
#       id  label
# 0  20800      0
# 1  20801      1
# 2  20802      1
# 3  20803      0
# 4  20804      1

# %%
submit.label = prediction1

# %%
submit.to_csv('submission1.csv',index=False)
